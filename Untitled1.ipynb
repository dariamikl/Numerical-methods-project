# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x0 = 1
y0 = 1
xb = 2.3
h = 0.1
n = int((xb-x0)/h)
# Out:
# 12

# %%
x = np.linspace(x0, xb, n)
x
# Out:
# array([1.        , 1.11818182, 1.23636364, 1.35454545, 1.47272727,
#        1.59090909, 1.70909091, 1.82727273, 1.94545455, 2.06363636,
#        2.18181818, 2.3       ])

# %%
y = np.zeros([n])

# %%
y[0] = y0
for i in range (1,n):
    y[i] = y[i-1] + h*(y[i-1]/x[i-1] + x[i-1]/y[i-1])
for i in range (n):
    print(f'{i}: {x[i]}: {y[i]}')
# Out:
# 0: 1.0: 1.0
# 1: 1.1181818181818182: 1.2
# 2: 1.2363636363636363: 1.4004988913525498
# 3: 1.3545454545454545: 1.6020547665432472
# 4: 1.4727272727272727: 1.8048777747730098
# 5: 1.5909090909090908: 2.0090282679089695
# 6: 1.709090909090909: 2.2144980341028866
# 7: 1.8272727272727272: 2.421247078064858
# 8: 1.9454545454545453: 2.6292213841426664
# 9: 2.0636363636363635: 2.838361839357312
# 10: 2.1818181818181817: 3.0486087923374643
# 11: 2.3: 3.259904362096066

# %%
# %matplotlib notebook
plt.plot(x,y,'o')
plt.xlabel('X value')
plt.ylabel('Y label')
plt.title("Euler method")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="637.7272589049066">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def euler():
    x0 = 1
    y0 = 1
    xb = 2.3
    h = 0.1
    n = int((xb-x0)/h)
    x = np.linspace(x0, xb, n)
    y = np.zeros([n])
    y[0] = y0
    for i in range (1,n):
        y[i] = y[i-1] + h*(y[i-1]/x[i-1] + x[i-1]/y[i-1])
    for i in range (n):
        print(f'{i}: {x[i]}: {y[i]}')
    # %matplotlib notebook
    plt.plot(x,y,'o')
    plt.xlabel('X value')
    plt.ylabel('Y label')
    plt.title("Euler method")
    plt.show
euler()
# Out:
# 0: 1.0: 1.0
# 1: 1.1181818181818182: 1.2
# 2: 1.2363636363636363: 1.4004988913525498
# 3: 1.3545454545454545: 1.6020547665432472
# 4: 1.4727272727272727: 1.8048777747730098
# 5: 1.5909090909090908: 2.0090282679089695
# 6: 1.709090909090909: 2.2144980341028866
# 7: 1.8272727272727272: 2.421247078064858
# 8: 1.9454545454545453: 2.6292213841426664
# 9: 2.0636363636363635: 2.838361839357312
# 10: 2.1818181818181817: 3.0486087923374643
# 11: 2.3: 3.259904362096066
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
def euler():
    x0 = 1
    y0 = 1
    xb = 2.3
    h = 0.1
    def f(x,y):
        return y/x + x/y
    n = int((xb-x0)/h)
    x = np.linspace(x0, xb, n)
    y = np.zeros([n])
    y[0] = y0
    for i in range (1,n):
        y[i] = y[i-1] + h*f(x[i-1], y[i-1])
    for i in range (n):
        print(f'{i}: {x[i]}: {y[i]}')
    # %matplotlib notebook
    plt.plot(x,y,'o')
    plt.xlabel('X value')
    plt.ylabel('Y label')
    plt.title("Euler method")
    plt.show
euler()
# Out:
# 0: 1.0: 1.0
# 1: 1.1181818181818182: 1.2
# 2: 1.2363636363636363: 1.4004988913525498
# 3: 1.3545454545454545: 1.6020547665432472
# 4: 1.4727272727272727: 1.8048777747730098
# 5: 1.5909090909090908: 2.0090282679089695
# 6: 1.709090909090909: 2.2144980341028866
# 7: 1.8272727272727272: 2.421247078064858
# 8: 1.9454545454545453: 2.6292213841426664
# 9: 2.0636363636363635: 2.838361839357312
# 10: 2.1818181818181817: 3.0486087923374643
# 11: 2.3: 3.259904362096066
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
def euler():
    x0 = 1
    y0 = 1
    xb = 2.3
    h = 1
    def f(x,y):
        return y/x + x/y
    n = int((xb-x0)/h)
    x = np.linspace(x0, xb, n)
    y = np.zeros([n])
    y[0] = y0
    for i in range (1,n):
        y[i] = y[i-1] + h*f(x[i-1], y[i-1])
    for i in range (n):
        print(f'{i}: {x[i]}: {y[i]}')
    plt.plot(x,y,'o')
   

def improved_euler():
    x0 = 1
    y0 = 1
    xb = 2.3
    h = 0.1
    def f(x,y):
        return y/x + x/y
    n = int((xb-x0)/h)
    x = np.linspace(x0, xb, n)
    y = np.zeros([n])
    y_p = np.zeros([n])
    y_p[0]=-1
    y[0] = y0
    for i in range (1,n):
        y_p[i]=y[i-1] + h*f(x[i-1], y[i-1])
        y[i] = y[i-1] + (h/2)*(f(x[i-1], y[i-1]) + f(x[i], y_p[i]))
    for i in range (n):
        print(f'{i}: {x[i]}: {y[i]}')
    return [x,y]

# %matplotlib notebook
#[x_e, y_e] = euler()
#[x_ie, y_ie] = improved_euler()
#plt.plot(x_e,y_e,'o')
#plt.plot(x_ie, y_ie, 'g')
plt.xlabel('X value')
plt.ylabel('Y label')
plt.title("Improved Euler method")
plt.show
euler()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 0: 1.0: 1.0

# %%
def euler():
    x0 = 1
    y0 = 1
    xb = 2.3
    h = 1
    def f(x,y):
        return y/x + x/y
    n = int((xb-x0)/h)
    x = np.linspace(x0, xb, n)
    y = np.zeros([n])
    y[0] = y0
    for i in range (1,n):
        y[i] = y[i-1] + h*f(x[i-1], y[i-1])
    for i in range (n):
        print(f'{i}: {x[i]}: {y[i]}')
    plt.plot(x,y,'o')
    plt.xlabel('X value')
    plt.ylabel('Y label')
    plt.title("Improved Euler method")
    plt.show
euler()
# Out:
# 0: 1.0: 1.0
